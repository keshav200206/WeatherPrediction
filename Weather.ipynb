# 2023-01-27  IN022021900  NEW DELHI SAFDARJUN, IN   NaN   NaN  55.0   NaN  42.0
# 2023-01-28  IN022021900  NEW DELHI SAFDARJUN, IN   NaN   NaN  57.0   NaN  43.0
# 2023-01-29  IN022021900  NEW DELHI SAFDARJUN, IN   NaN   NaN  56.0  75.0  44.0
# 2023-01-30  IN022021900  NEW DELHI SAFDARJUN, IN  0.79   NaN  58.0  66.0  50.0
# 2023-01-31  IN022021900  NEW DELHI SAFDARJUN, IN  0.00   NaN  59.0   NaN  50.0

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.354718
# SNWD       0.999911
# TAVG       0.146396
# TMAX       0.263031
# TMIN       0.286643
# dtype: float64

# %%
core_weather = weather[["PRCP","SNWD","TMAX","TMIN"]].copy()

# %%
core_weather.columns = ["precip","snow_depth","temp_max","temp_min"]

# %%
core_weather
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01     0.0         NaN       NaN       NaN
# 1960-01-02     0.0         NaN       NaN       NaN
# 1960-01-03     0.0         NaN       NaN       NaN
# 1960-01-04     0.0         NaN       NaN       NaN
# 1960-01-05     0.0         NaN       NaN       NaN
# ...            ...         ...       ...       ...
# 2023-11-04     NaN         NaN      86.0      62.0
# 2023-11-05     NaN         NaN       NaN      60.0
# 2023-11-06     NaN         NaN      89.0      56.0
# 2023-11-07     NaN         NaN      89.0      59.0
# 2023-11-08     NaN         NaN      89.0      59.0
#
# [22446 rows x 4 columns]

# %%
core_weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# precip        0.354718
# snow_depth    0.999911
# temp_max      0.263031
# temp_min      0.286643
# dtype: float64

# %%
core_weather["precip"].value_counts()
# Out:
# precip
# 0.00    11436
# 0.04      252
# 0.02      232
# 0.08      227
# 0.01      185
#         ...
# 5.12        1
# 1.67        1
# 3.09        1
# 1.39        1
# 4.21        1
# Name: count, Length: 265, dtype: int64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# snow_depth
# 5.1    1
# 8.7    1
# Name: count, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1973-01-01     NaN       NaN       NaN
# 1973-01-02     NaN       NaN       NaN
# 1973-01-03     NaN       NaN       NaN
# 1973-01-04     NaN       NaN       NaN
# 1973-01-05     NaN       NaN      46.0
# ...            ...       ...       ...
# 2023-11-04     NaN      86.0      62.0
# 2023-11-05     NaN       NaN      60.0
# 2023-11-06     NaN      89.0      56.0
# 2023-11-07     NaN      89.0      59.0
# 2023-11-08     NaN      89.0      59.0
#
# [7962 rows x 3 columns]

# %%
core_weather.loc["1972-12-20":"1973-01-20",:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1973-01-01     NaN       NaN       NaN
# 1973-01-02     NaN       NaN       NaN
# 1973-01-03     NaN       NaN       NaN
# 1973-01-04     NaN       NaN       NaN
# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1960-01-01    0.00       NaN       NaN
# 1960-01-02    0.00       NaN       NaN
# 1960-01-03    0.00       NaN       NaN
# 1960-01-04    0.00       NaN       NaN
# 1960-01-05    0.00       NaN       NaN
# ...            ...       ...       ...
# 2023-08-22    0.00     101.0       NaN
# 2023-09-16    0.04      94.0       NaN
# 2023-09-21    0.00      99.0       NaN
# 2023-09-23    0.00      98.0       NaN
# 2023-10-16    0.00      94.0       NaN
#
# [6434 rows x 3 columns]

# %%
core_weather = core_weather.ffill()

# %%
core_weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# precip      0.000000
# temp_max    0.000223
# temp_min    0.000223
# dtype: float64

# %%
core_weather["temp_max"] = core_weather["temp_max"].fillna(0)

# %%
core_weather["temp_min"] = core_weather["temp_min"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# precip      0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04', '1960-01-05',
#        '1960-01-06', '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#        ...
#        '2023-10-30', '2023-10-31', '2023-11-01', '2023-11-02', '2023-11-03',
#        '2023-11-04', '2023-11-05', '2023-11-06', '2023-11-07', '2023-11-08'],
#       dtype='object', name='DATE', length=22446)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2023-10-30', '2023-10-31', '2023-11-01', '2023-11-02',
#                '2023-11-03', '2023-11-04', '2023-11-05', '2023-11-06',
#                '2023-11-07', '2023-11-08'],
#               dtype='datetime64[ns]', name='DATE', length=22446, freq=None)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.44.0-cp312-cp312-win_amd64.whl.metadata (156 kB)
#      ---------------------------------------- 0.0/156.8 kB ? eta -:--:--
#      --------------- ----------------------- 61.4/156.8 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 156.8/156.8 kB 3.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in d:\python3\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in d:\python3\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading Pillow-10.1.0-cp312-cp312-win_amd64.whl.metadata (9.6 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\python3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.1-cp312-cp312-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/7.6 MB 12.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.8/7.6 MB 10.8 MB/s eta 0:00:01
#    ------- -------------------------------- 1.4/7.6 MB 11.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.6 MB 11.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/7.6 MB 11.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.0/7.6 MB 11.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/7.6 MB 11.4 MB/s eta 0:00:01
#    -------------------- ------------------- 4.0/7.6 MB 11.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.5/7.6 MB 11.4 MB/s eta 0:00:01
#    ------------------------- -------------- 4.9/7.6 MB 10.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.2/7.6 MB 10.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.6 MB 10.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.3/7.6 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.0/7.6 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 10.6 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp312-cp312-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.7 kB ? eta -:--:--
#    --------------------------------------- 187.7/187.7 kB 11.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.44.0-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/2.1 MB 10.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.1 MB 8.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.1 MB 10.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------- -- 2.0/2.1 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 9.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB ? eta 0:00:00
# Downloading Pillow-10.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 10.9 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.6 MB 12.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 12.0 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.6 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 9.2 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.44.0 kiwisolver-1.4.5 matplotlib-3.8.1 pillow-10.1.0 pyparsing-3.1.1

# %%
core_weather[["temp_max","temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1960    365
# 1961    365
# 1962    365
# 1963    365
# 1964    365
#        ...
# 2019    361
# 2020    366
# 2021    362
# 2022    365
# 2023    312
# Name: count, Length: 62, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1960    30.10
# 1961    43.92
# 1962    22.69
# 1963    31.64
# 1964    48.48
#         ...
# 2019    19.56
# 2020    30.87
# 2021    46.04
# 2022    24.90
# 2023    31.45
# Name: precip, Length: 62, dtype: float64

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0       0.0       0.0     0.0
# 1960-01-02     0.0       0.0       0.0     0.0
# 1960-01-03     0.0       0.0       0.0     0.0
# 1960-01-04     0.0       0.0       0.0     0.0
# 1960-01-05     0.0       0.0       0.0    70.0
# ...            ...       ...       ...     ...
# 2023-11-04     0.0      86.0      62.0    86.0
# 2023-11-05     0.0      86.0      60.0    89.0
# 2023-11-06     0.0      89.0      56.0    89.0
# 2023-11-07     0.0      89.0      59.0    89.0
# 2023-11-08     0.0      89.0      59.0     NaN
#
# [22446 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0       0.0       0.0     0.0
# 1960-01-02     0.0       0.0       0.0     0.0
# 1960-01-03     0.0       0.0       0.0     0.0
# 1960-01-04     0.0       0.0       0.0     0.0
# 1960-01-05     0.0       0.0       0.0    70.0
# ...            ...       ...       ...     ...
# 2023-11-03     0.0      86.0      62.0    86.0
# 2023-11-04     0.0      86.0      62.0    86.0
# 2023-11-05     0.0      86.0      60.0    89.0
# 2023-11-06     0.0      89.0      56.0    89.0
# 2023-11-07     0.0      89.0      59.0    89.0
#
# [22445 rows x 4 columns]

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in d:\python3\lib\site-packages (from scikit-learn) (1.26.1)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Downloading scipy-1.11.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.4 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 60.4/60.4 kB 1.6 MB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.3.2-cp312-cp312-win_amd64.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB 9.3 MB/s eta 0:00:01
#    --- ------------------------------------ 0.7/9.1 MB 8.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/9.1 MB 9.0 MB/s eta 0:00:01
#    ------ --------------------------------- 1.5/9.1 MB 9.2 MB/s eta 0:00:01
#    ------- -------------------------------- 1.7/9.1 MB 8.2 MB/s eta 0:00:01
MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 43.7/43.7 MB 8.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 scipy-1.11.3 threadpoolctl-3.2.0

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip","temp_max","temp_min"]

# %%
train = core_weather.loc[:"2022-12-31"]

# %%
test = core_weather.loc["2023-01-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 1.8677517399607482

# %%
combined = pd.concat([test["target"],pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2023-01-01    70.0    69.785535
# 2023-01-02    63.0    70.803412
# 2023-01-03    61.0    64.228181
# 2023-01-04    62.0    62.231707
# 2023-01-05    62.0    63.112107
# ...            ...          ...
# 2023-11-03    86.0    86.146742
# 2023-11-04    86.0    86.146742
# 2023-11-05    89.0    86.107463
# 2023-11-06    89.0    88.846861
# 2023-11-07    89.0    88.905780
#
# [311 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([0.47053243, 0.93931869, 0.01963947])

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2022-12-31"]
    test = core_weather.loc["2023-01-01":]
    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])
    error = mean_absolute_error(test["target"], predictions)
    combined = pd.concat([test["target"],pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max
# DATE
# 1960-01-01     0.0       0.0       0.0     0.0        NaN
# 1960-01-02     0.0       0.0       0.0     0.0        NaN
# 1960-01-03     0.0       0.0       0.0     0.0        NaN
# 1960-01-04     0.0       0.0       0.0     0.0        NaN
# 1960-01-05     0.0       0.0       0.0    70.0        NaN
# ...            ...       ...       ...     ...        ...
# 2023-11-03     0.0      86.0      62.0    86.0  91.833333
# 2023-11-04     0.0      86.0      62.0    86.0  91.566667
# 2023-11-05     0.0      86.0      60.0    89.0  91.266667
# 2023-11-06     0.0      89.0      56.0    89.0  91.000000
# 2023-11-07     0.0      89.0      59.0    89.0  90.733333
#
# [22445 rows x 5 columns]

# %%
core_weather["month_day_max"] = core_weather["month_max"]/ core_weather["temp_max"]

# %%
core_weather["max_min"] = core_weather["temp_max"]/ core_weather["temp_min"]

# %%
predictors = ["precip","temp_max","temp_min", "month_day_max","max_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# 1.9368536933368954

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather.groupby(core_weather.index.month)["temp_max"].expanding(1).mean().reset_index(level=0, drop=True)

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1960-01-31     0.0      75.0      48.0    72.0  60.133333       0.801778
# 1960-02-01     0.0      72.0      52.0    72.0  62.533333       0.868519
# 1960-02-02     0.0      72.0      52.0    72.0  64.933333       0.901852
# 1960-02-03     0.0      72.0      52.0    75.0  67.333333       0.935185
# 1960-02-04     0.0      75.0      45.0    75.0  69.833333       0.931111
# ...            ...       ...       ...     ...        ...            ...
# 2023-11-03     0.0      86.0      62.0    86.0  91.833333       1.067829
# 2023-11-04     0.0      86.0      62.0    86.0  91.566667       1.064729
# 2023-11-05     0.0      86.0      60.0    89.0  91.266667       1.061240
# 2023-11-06     0.0      89.0      56.0    89.0  91.000000       1.022472
# 2023-11-07     0.0      89.0      59.0    89.0  90.733333       1.019476
#
#              max_min  monthly_avg
# DATE
# 1960-01-31  1.562500    75.000000
# 1960-02-01  1.384615    72.000000
# 1960-02-02  1.384615    72.000000
# 1960-02-03  1.384615    72.000000
# 1960-02-04  1.666667    72.750000
# ...              ...          ...
# 2023-11-03  1.387097    84.114395
# 2023-11-04  1.387097    84.115427
# 2023-11-05  1.433333    84.116457
# 2023-11-06  1.589286    84.119126
# 2023-11-07  1.508475    84.121791
#
# [22415 rows x 8 columns]

# %%
core_weather["day_of_year_avg"] = core_weather.groupby(core_weather.index.day_of_year)["temp_max"].expanding(1).mean().reset_index(level=0, drop=True)

# %%
predictors = ["precip","temp_max","temp_min","month_max","month_day_max","max_min","day_of_year_avg","monthly_avg"]

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# 1.9444140524541043

# %%
reg.coef_
# Out:
# array([ 1.11219089e-01,  8.66195221e-01, -3.00601950e-03,  1.58265408e-02,
#         3.52137161e+00, -5.88084398e-01,  1.90728459e-01, -4.02751741e-02])

# %%
core_weather.corr()["target"]
# Out:
# precip             0.007663
# temp_max           0.960494
# temp_min           0.682463
# target             1.000000
# month_max          0.875347
# month_day_max     -0.334577
# max_min           -0.210097
# monthly_avg        0.820478
# day_of_year_avg    0.859198
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff",ascending=False).head()
# Out:
#             actual  predictions       diff
# DATE
# 2023-05-25    98.0   108.940000  10.940000
# 2023-04-30    84.0    93.647644   9.647644
# 2023-07-09    87.0    96.405809   9.405809
# 2023-05-31    89.0    98.212579   9.212579
# 2023-02-16    84.0    74.836830   9.163170
